# %%
import pybd_gui
app = pybd_gui.pybd_gui()
app.mainloop()
# Out:
# sticky = n
# sticky = n
# chosen_type: h_bridge
# go button pressed
# chosen_type: h_bridge
# variable_name: h_bridge_act
# kwargs = {'variable_name': 'h_bridge_act', 'in1_pin': 6, 'in2_pin': 4, 'pwm_pin': 9}
# chosen_type: encoder
# go button pressed
# chosen_type: encoder
# variable_name: encoder_sensor
# kwargs = {'variable_name': 'encoder_sensor', 'pinB': 11, 'interrupt_number': 0}
# currow = 5
# currow = 6
# currow = 7
# currow = 8
# block type selection:
# (3,)
# block_type: fixed_sine_input
# block py_params:
# freq : 1
# amp : 100
# you pressed go
# block_type: fixed_sine_input
# plant classes: ['plant', 'i2c_plant', 'plant_no_actuator', 'plant_with_double_actuator', 'plant_with_double_actuator_two_sensors', 'plant_with_two_i2c_inputs_and_two_i2c_sensors', 'cart_pendulum', 'cart_pendulum_v2']
# creating block in go_pressed
# kwargs:
# {'freq': 1, 'amp': 100}
# block_name: U
# in create block, kwargs:
# {'freq': 1, 'amp': 100}
# selected_indices: 0
# setting abs defaults
# ...
